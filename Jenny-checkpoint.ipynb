# %%
# importations des données

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# prenons la copie de notre dataframe, c'est la copie qu'on va faire nos analyses
copy_data = data.copy()

# %%
copy_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# verifions la taille de la matrice
copy_data.shape
# Out:
# (7043, 21)

# %%
#informations sur les données
copy_data.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
# verifions le types de nos données
copy_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# information sur les données
copy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# description de la datafame
copy_data.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     9670-BPNXF   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
copy_data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# verification des valeurs nulles
copy_data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#nombres des clients churneurs et non churneurs
copy_data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
#visualisons les clients churneurs
sns.countplot(copy_data['Churn'])

# %%
copy_data['Churn'].value_counts(normalize=True).plot.pie()

# %%
#voyons le taux des clients qui peuvent partir cad les churneurs et ceux qui vont rester
clientChurn = data[data.Churn == 'Yes'].shape[0]
clientNoChurn = data[data.Churn == 'No'].shape[0]

print ('clients partants = ', clientChurn/ (clientChurn + clientNoChurn)*100)
print ('clients restants = ', clientNoChurn/ (clientChurn + clientNoChurn)*100)
# Out:
# clients partants =  26.536987079369588
# clients restants =  73.4630129206304

# %%
# voyons quels sont les clients churneurs en se basant sur le genre
#sns.countplot(x='Partner', hue='Churn', donnees = data)

# %%
# le churn par rapport aux données numeriques
donneNumeric=['tenure','MonthlyCharges']
fig, ax = plt.subplots(1, 2, figsize=(28,8))
data[data.Churn == 'No'][donneNumeric].hist(bins=20, color='green', alpha=0.5, ax=ax)
data[data.Churn == 'Yes'][donneNumeric].hist(bins=20, color='yellow', alpha=0.5, ax=ax)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002AC6D84D108>,
# ...
#       dtype=object)

# %%
#netoyage de notre dataset, on enleve les données non pertinentes
data_clean= data.drop('customerID', axis = 1)

# %%
data_clean.shape
# Out:
# (7043, 20)

# %%
 # encodage des données
for column in data_clean.columns:
    if data_clean[column].dtype == np.number:
        continue
    data_clean[column] = LabelEncoder().fit_transform(data_clean[column])

# %%
data_clean.dtypes
# Out:
# gender                int32
# SeniorCitizen         int64
# Partner               int32
# Dependents            int32
# tenure                int64
# PhoneService          int32
# MultipleLines         int32
# InternetService       int32
# OnlineSecurity        int32
# OnlineBackup          int32
# DeviceProtection      int32
# TechSupport           int32
# StreamingTV           int32
# StreamingMovies       int32
# Contract              int32
# PaperlessBilling      int32
# PaymentMethod         int32
# MonthlyCharges      float64
# TotalCharges          int32
# Churn                 int32
# dtype: object

# %%
# visualosons le head de notre nouveau dataset
data_clean.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
#scaler notre dataset
x = data_clean.drop('Churn', axis= 1)
y = data_clean['Churn']
x = StandardScaler().fit_transform(x)

# %%
# divisons notre dataset en données de test (20%) et données d'apprentissage (80%)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
#creeons notre modele
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import learning_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
modele = LogisticRegression()

# %%
mode1=DecisionTreeClassifier(random_state=0)
model_2=SVC(random_state=0)
model_3=RandomForestClassifier(random_state=0)
model_4=AdaBoostClassifier(random_state=0)
model_5=SGDClassifier()

# %%
liste_des_modeles={'Decision Tree':mode1,'SVC':model_2,'RandF':model_3,'Adabo': model_4,'SDGC':model_5}

# %%
#apprenons le modele
modele.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# prediction aux données de test
prediction = modele.predict(x_test)

# %%
prediction
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
# courbes d'apprentissage
def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    
    if axes is None:
        _, axes = plt.subplots(1, 3, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Apprentissage")
    axes[0].set_ylabel("Score")

    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs,
                       train_sizes=train_sizes,
                       return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Score sur l'apprentisage")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Score sur la validation")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Apprentisage")
    axes[1].set_ylabel("Temps d'évolution")
    axes[1].set_title("Evolution du model")

    # Plot fit_time vs score
    axes[2].grid()
    axes[2].plot(fit_times_mean, test_scores_mean, 'o-')
    axes[2].fill_between(fit_times_mean, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1)
    axes[2].set_xlabel("Temps d'évolution")
    axes[2].set_ylabel("Score")
    axes[2].set_title("Performance du modele")

    return plt

# %%
# evaluons le modèle avec la matrice de confusion
def evaluation(modele):
        modele.fit(x_train, y_train)
        ypred=modele.predict(x_test)
        
        print(confusion_matrix(y_test, ypred))
        print(classification_report(y_test, ypred))
        
        fig, axes = plt.subplots(3, 1, figsize=(10, 15))

        plot_learning_curve(modele, "Courbe",x_train, y_train, axes=axes, ylim=(0.7, 1.01), cv=4, n_jobs=4)
        plt.show()

# %%
# voyons la precision, le recall et f1-score
print(classification_report(y_test, prediction))
for nom, model in liste_des_modeles.items():
    print(nom)
    evaluation(modele)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      1036
#            1       0.69      0.56      0.62       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.74      0.75      1409
# weighted avg       0.81      0.82      0.81      1409
#
# Decision Tree
# [[940  96]
#  [163 210]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      1036
#            1       0.69      0.56      0.62       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.74      0.75      1409
# weighted avg       0.81      0.82      0.81      1409
# SVC
# [[940  96]
#  [163 210]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      1036
#            1       0.69      0.56      0.62       373
#
#     accuracy                           0.82      1409
# ...

# %%
pickle.dump(classification_report, open('modelChurn.pkl','wb'))
